# %% [markdown]
# Ensemble hard-voting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 43.8 MB/s
# ...
#      |████████████████████████████████| 448 kB 40.6 MB/s
# ...

# %%
import pandas as pd

a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pp__kobigbird(2.353).csv')
a = a.drop(['Context', 'Question', 'guid'], axis=1)
a = a.drop(0, axis=0)
a = a.rename(columns={'Predicted':'Predicted_a', 'levenshtein':'levenshtein_a', 'Start':'Start_a', 'End':'End_a', 'Score':'Score_a'})
a
# Out:
#       Unnamed: 0                                Answer  \
# 1              1  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 2              2                          ['독일 뒤셀도르프']
# 3              3                              ['페이스북']
# 4              4                              ['페이스북']
# 5              5                              ['마드리드']
# ...          ...                                   ...
# 4003        4003                             ['200만엔']
# 4004        4004                    ['중동 건설 현장', '중동']
# 4005        4005               ['아시아~유럽 노선', '아시아~유럽']
# 4006        4006                                ['사흘']
# 4007        4007                               ['벨기에']
#
#                                     Id       Predicted_a  Start_a  End_a  \
# 1     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션    666.0  682.0
# 2     906631384e91493ebe1c7f34aea6f241          독일 뒤셀도르프    556.0  565.0
# 3     35e61dcb479643448a2cb7d326ae50a6              페이스북    543.0  548.0
# ...

# %%
dfa = a.drop_duplicates(subset=['Id'])
dfa
# Out:
#       Unnamed: 0                                Answer  \
# 1              1  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 2              2                          ['독일 뒤셀도르프']
# 3              3                              ['페이스북']
# 4              4                              ['페이스북']
# 5              5                              ['마드리드']
# ...          ...                                   ...
# 4003        4003                             ['200만엔']
# 4004        4004                    ['중동 건설 현장', '중동']
# 4005        4005               ['아시아~유럽 노선', '아시아~유럽']
# 4006        4006                                ['사흘']
# 4007        4007                               ['벨기에']
#
#                                     Id       Predicted_a  Start_a  End_a  \
# 1     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션    666.0  682.0
# 2     906631384e91493ebe1c7f34aea6f241          독일 뒤셀도르프    556.0  565.0
# 3     35e61dcb479643448a2cb7d326ae50a6              페이스북    543.0  548.0
# ...

# %%
b = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hh_koelectra-base-v3-discriminator-finetuned-klue_check(3.46_3.350).csv')
b = b.drop(['Context', 'Question', 'guid','levenshtein'], axis=1)
b = b.rename(columns={'Predicted':'Predicted_b', 'Start':'Start_b', 'End':'End_b', 'Score':'Score_b'})
b
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 1              1                             ['블루스퀘어']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id       Predicted_b  Start_b   End_b  \
# 0     6727d61923604c60b41d864c00c1a89a               NaN    578.0   582.0
# 1     6727d61923604c60b41d864c00c1a89a               NaN    578.0   582.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션    666.0   682.0
# ...

# %%
dfb = b.drop_duplicates(subset=['Id'])
dfb
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# 5              5                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id       Predicted_b  Start_b   End_b  \
# 0     6727d61923604c60b41d864c00c1a89a               NaN    578.0   582.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션    666.0   682.0
# 3     906631384e91493ebe1c7f34aea6f241             뒤셀도르프    559.0   565.0
# ...

# %%
c = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pp_xlm-roberta-base_check(3.65_3.534).csv')
c = c.drop(['Context', 'Question', 'guid'], axis=1)
c = c.rename(columns={'Predicted':'Predicted_c', 'Start':'Start_c', 'End':'End_c', 'Score':'Score_c'})
c
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 1              1                             ['블루스퀘어']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id         Predicted_c  Start_c  End_c  \
# 0     6727d61923604c60b41d864c00c1a89a                  루케    578.0  582.0
# 1     6727d61923604c60b41d864c00c1a89a                  루케    578.0  582.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션(7    666.0  685.0
# ...

# %%
dfc = c.drop_duplicates(subset=['Id'])
dfc
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# 5              5                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id         Predicted_c  Start_c  End_c  \
# 0     6727d61923604c60b41d864c00c1a89a                  루케    578.0  582.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션(7    666.0  685.0
# 3     906631384e91493ebe1c7f34aea6f241               뒤셀도르프    559.0  565.0
# ...

# %%
d = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bert-base-multilingual-cased_check(3.78_3.667).csv')
d = d.drop(['Context', 'Question', 'guid'], axis=1)
d = d.rename(columns={'Predicted':'Predicted_d', 'Start':'Start_d', 'End':'End_d', 'Score':'Score_d'})
d
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 1              1                             ['블루스퀘어']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id      Predicted_d  Start_d   End_d  \
# 0     6727d61923604c60b41d864c00c1a89a              NaN   1316.0  1320.0
# 1     6727d61923604c60b41d864c00c1a89a              NaN   1316.0  1320.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 520d 25주년 에디션    471.0   486.0
# ...

# %%
dfd = d.drop_duplicates(subset=['Id'])
dfd
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# 5              5                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id      Predicted_d  Start_d   End_d  \
# 0     6727d61923604c60b41d864c00c1a89a              NaN   1316.0  1320.0
# 2     d14cb73158624cf094c546d856fd3c80  뉴 520d 25주년 에디션    471.0   486.0
# 3     906631384e91493ebe1c7f34aea6f241       프랑스 남부 알프스      0.0    11.0
# ...

# %%
e = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/koelectra-base-v3-finetuned-korquad_check(3.34_3.24).csv')
e = e.drop(['Context', 'Question', 'guid', 'levenshtein'], axis=1)
e = e.rename(columns={'Predicted':'Predicted_e', 'Start':'Start_e', 'End':'End_e', 'Score':'Score_e'})
e
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 1              1                             ['블루스퀘어']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id       Predicted_e  Start_e  End_e  \
# 0     6727d61923604c60b41d864c00c1a89a               NaN     1112   1138
# 1     6727d61923604c60b41d864c00c1a89a               NaN     1112   1138
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션      666    682
# ...

# %%
dfe = e.drop_duplicates(subset=['Id'])
dfe
# Out:
#       Unnamed: 0                                Answer  \
# 0              0                           ['터키 이스탄불']
# 2              2  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 3              3                          ['독일 뒤셀도르프']
# 4              4                              ['페이스북']
# 5              5                              ['페이스북']
# ...          ...                                   ...
# 4004        4004                             ['200만엔']
# 4005        4005                    ['중동 건설 현장', '중동']
# 4006        4006               ['아시아~유럽 노선', '아시아~유럽']
# 4007        4007                                ['사흘']
# 4008        4008                               ['벨기에']
#
#                                     Id       Predicted_e  Start_e  End_e  \
# 0     6727d61923604c60b41d864c00c1a89a               NaN     1112   1138
# 2     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션      666    682
# 3     906631384e91493ebe1c7f34aea6f241          독일 뒤셀도르프      556    565
# ...

# %%
df1 = pd.merge(dfa, dfb, how='inner', on = 'Id')
df1 = df1.drop(['Answer_x'], axis=1)
df2 = pd.merge(df1, dfc, how='inner', on = 'Id')
df2 = df2.drop(['Answer'], axis=1)
df3 = pd.merge(df2, dfd, how='inner', on = 'Id')
df3 = df3.drop(['Answer'], axis=1)
df4 = pd.merge(df3, dfe, how='inner', on = 'Id')
#df4 = df4.drop(['Answer_x'], axis=1)
df4 = df4.rename(columns={ 'Predicted_c_y':'Predicted_c', 'Predicted_d_y':'Predicted_d', 'Predicted_e_y':'Predicted_e'})
pd.set_option('display.max_columns', None)
df = df4
df = df.drop(['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0_y', 'Answer_y'], axis=1)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   """
#                                     Id       Predicted_a  Start_a  End_a  \
# 0     d14cb73158624cf094c546d856fd3c80  뉴 740Li 25주년 에디션    666.0  682.0
# 1     906631384e91493ebe1c7f34aea6f241          독일 뒤셀도르프    556.0  565.0
# 2     35e61dcb479643448a2cb7d326ae50a6              페이스북    543.0  548.0
# 3     075e761b370040cb9041eecd39afc27c              페이스북    543.0  548.0
# 4     e67ed38f3dd944be94d5b4c53731f334              마드리드    408.0  413.0
# ...                                ...               ...      ...    ...
# 4002  05fcb8054dc44dab8683579c2cf5e465              2만달러    546.0  551.0
# 4003  cc7f826b66724ce9b39e3a974ca15661          중동 건설 현장    470.0  480.0
# 4004  3282034aa41e4fab980851ffd4a868dd         아시아~유럽 노선    383.0  393.0
# ...

# %%
#df.to_csv('/content/drive/MyDrive/Colab Notebooks/fivemodels.csv')

# %%
answer = df.drop(['Predicted_a', 'Predicted_b', 'Predicted_c','Start_a','Start_b', 'Start_c', 'Predicted_b', 'End_a','End_b', 'End_c','Score_b', 'Score_a', 'Score_c', 'Predicted_d', 'Start_d', 'End_d', 'Score_d', 'Predicted_e', 'Start_e', 'End_e', 'Score_e'], axis=1)
answer['predict'] = None
answer
# Out:
#                                     Id                                Answer  \
# 0     d14cb73158624cf094c546d856fd3c80  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 1     906631384e91493ebe1c7f34aea6f241                          ['독일 뒤셀도르프']
# 2     35e61dcb479643448a2cb7d326ae50a6                              ['페이스북']
# 3     075e761b370040cb9041eecd39afc27c                              ['페이스북']
# 4     e67ed38f3dd944be94d5b4c53731f334                              ['마드리드']
# ...                                ...                                   ...
# 4002  05fcb8054dc44dab8683579c2cf5e465                             ['200만엔']
# 4003  cc7f826b66724ce9b39e3a974ca15661                    ['중동 건설 현장', '중동']
# 4004  3282034aa41e4fab980851ffd4a868dd               ['아시아~유럽 노선', '아시아~유럽']
# 4005  0a73550b36df4baf82ac2f98619d22e7                                ['사흘']
# 4006  dfe6ef25f84f461e89e54d370e4521d5                               ['벨기에']
#
#      predict
# 0       None
# 1       None
# ...

# %%
# a가 성능이 가장 좋음(kobigbird)(2.4)
# b = koelectra(3.35)
# c = xlm_roberta(3.53)
# d = bert-base(3.66)
# e = koelectra(3.24)

for i in range(4007):
  num = 0
  # a, b, c, d, e의 값이 모두 같을 때
  if df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  
  # a, b, c, d, e의 값 중 4가지만 같을 때
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] == df.loc[i,'Predicted_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_e'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  
  # a, b, c, d, e의 값 중 3가지만 같을 때
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_a'] == df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  
  # a, b, c, d, e의 값 중 2가지만 같을 때
    # a, b가 같고, c, d가 같지만, e가 a에 포함되어 있는 단어 일 때
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (df.loc[i,'Predicted_e'] in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']

  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']

    # a, b가 같고, c, d가 같지만, c가 a안에 포함될 때
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']

  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_a']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_a']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_d'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_d']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_d'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_e'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_b']) in df.loc[i, 'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d'] and (str(df.loc[i,'Predicted_c']) in df.loc[i, 'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']

    # a, b가 같고, c, d가 같지만, e는 다를 때
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
    if df.loc[i, 'Score_a'] + df.loc[i, 'Score_b'] >= df.loc[i,'Score_c'] + df.loc[i,'Score_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_d']:
    if df.loc[i, 'Score_a'] + df.loc[i, 'Score_c'] >= df.loc[i,'Score_b'] + df.loc[i,'Score_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_b'] == df.loc[i,'Predicted_c']:
    if df.loc[i, 'Score_a'] + df.loc[i, 'Score_e'] >= df.loc[i,'Score_b'] + df.loc[i,'Score_c']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
    if df.loc[i, 'Score_a'] + df.loc[i, 'Score_e'] >= df.loc[i,'Score_c'] + df.loc[i,'Score_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e'] and df.loc[i,'Predicted_c'] == df.loc[i,'Predicted_d']:
    if df.loc[i, 'Score_b'] + df.loc[i, 'Score_e'] >= df.loc[i,'Score_c'] + df.loc[i,'Score_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  
    # a, b가 같고 나머지는 다 다를 때
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_b']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_c']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_a'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_c']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_b'] == df.loc[i,'Predicted_e']:
    if str(df.loc[i, 'Predicted_c']) in str(df.loc[i,'Predicted_a']):
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Predicted_c'] == df.loc[i,'Predicted_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_c'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Predicted_d'] == df.loc[i,'Predicted_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']

  # a, b, c, d, e가 다 다를 때
  elif str(df.loc[i, 'Predicted_a']) in str(df.loc[i,'Predicted_b']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif str(df.loc[i, 'Predicted_a']) in str(df.loc[i,'Predicted_c']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif str(df.loc[i, 'Predicted_a']) in str(df.loc[i,'Predicted_d']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif str(df.loc[i, 'Predicted_a']) in str(df.loc[i,'Predicted_e']):
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']

    # start가 전부 같을 때 
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d'] == df.loc[i,'Start_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
    
    # start가 4개 같을 때. 모델의 편집거리에 따라 가장 낮은 편집거리를 가진 예측 값을 넣음
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_e'] == df.loc[i,'Start_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_e'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_e'] == df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']  

    # start가 3개 같을 때. 모델의 편집거리에 따라 가장 낮은 편집거리를 가진 예측 값을 넣음
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_c']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_b'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_c'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_a'] == df.loc[i,'Start_d'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_d']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i,'Start_b'] == df.loc[i,'Start_c'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
  elif df.loc[i,'Start_b'] == df.loc[i,'Start_d'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
  elif df.loc[i,'Start_c'] == df.loc[i,'Start_d'] == df.loc[i,'Start_e']:
    answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
  
    # start가 2개 같을 때
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_b']:
    if df.loc[i, 'End_a'] >= df.loc[i,'End_b']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_c']:
    if df.loc[i, 'End_a'] >= df.loc[i,'End_c']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_d']:
    if df.loc[i, 'End_a'] >= df.loc[i,'End_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_a'] == df.loc[i,'Start_e']:
    if df.loc[i, 'End_a'] >= df.loc[i,'End_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_a']
  elif df.loc[i, 'Start_b'] == df.loc[i,'Start_c']:
    if df.loc[i, 'End_b'] >= df.loc[i,'End_c']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Start_b'] == df.loc[i,'Start_d']:
    if df.loc[i, 'End_b'] >= df.loc[i,'End_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Start_b'] == df.loc[i,'Start_e']:
    if df.loc[i, 'End_b'] >= df.loc[i,'End_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_b']
  elif df.loc[i, 'Start_c'] == df.loc[i,'Start_d']:
    if df.loc[i, 'End_c'] >= df.loc[i,'End_d']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Start_c'] == df.loc[i,'Start_e']:
    if df.loc[i, 'End_c'] >= df.loc[i,'End_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_c']
  elif df.loc[i, 'Start_d'] == df.loc[i,'Start_e']:
    if df.loc[i, 'End_d'] >= df.loc[i,'End_e']:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_e']
    else:
      answer.loc[i, 'predict'] = df.loc[i, 'Predicted_d']

    # 아예 다 다르고, 비슷한 것도 없을 때
  else:
    answer.loc[i, 'predict'] = None

# %%
answer
# Out:
#                                     Id                                Answer  \
# 0     d14cb73158624cf094c546d856fd3c80  ['뉴 740Li 25주년 에디션', '뉴 740Li 25주년']
# 1     906631384e91493ebe1c7f34aea6f241                          ['독일 뒤셀도르프']
# 2     35e61dcb479643448a2cb7d326ae50a6                              ['페이스북']
# 3     075e761b370040cb9041eecd39afc27c                              ['페이스북']
# 4     e67ed38f3dd944be94d5b4c53731f334                              ['마드리드']
# ...                                ...                                   ...
# 4002  05fcb8054dc44dab8683579c2cf5e465                             ['200만엔']
# 4003  cc7f826b66724ce9b39e3a974ca15661                    ['중동 건설 현장', '중동']
# 4004  3282034aa41e4fab980851ffd4a868dd               ['아시아~유럽 노선', '아시아~유럽']
# 4005  0a73550b36df4baf82ac2f98619d22e7                                ['사흘']
# 4006  dfe6ef25f84f461e89e54d370e4521d5                               ['벨기에']
#
#                predict
# ...

# %%
answer.to_csv('/content/drive/MyDrive/Colab Notebooks/answers.csv')
